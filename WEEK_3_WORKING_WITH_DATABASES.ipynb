# %% [markdown]
# <a href="https://colab.research.google.com/github/Graobri/COMP-593/blob/Lab-3/WEEK_3_WORKING_WITH_DATABASES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
myConnection.commit()
myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (2,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (3,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (4,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (5,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (6,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (7,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (8,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (9,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (10,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (11,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (12,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (13,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (14,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (15,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (16,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (17,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (18,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (19,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (20,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (21,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (22,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (23,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (24,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (25,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (26,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 21:24:42.246494',
#   '2021-02-16 21:24:42.246506',
#   None),
#  (27,
#   'Stacie Williams',
#   'barronjose@hotmail.com',
#   '0854 Scott Land\nShellymouth, NU A6G3H1',
#   'North Susan',
#   'Ontario',
#   'Ethiopia',
#   '+1 (172) 828-8568',
#   'cultivate turn-key infrastructures',
#   '2000-12-12',
#   1213,
#   '2021-02-16 23:15:04.401778',
#   '2021-02-16 23:15:04.401780',
#   '39.175.191.3'),
#  (28,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 23:18:07.636775',
#   '2021-02-16 23:18:07.636784',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in /usr/local/lib/python3.6/dist-packages (6.4.1)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.6/dist-packages (from faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.6/dist-packages (from faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {}'.format( fake.name(), fake.job() ) )
# Out:
# Kimberly Robertson || Agricultural engineer
# Megan Hardy || Land/geomatics surveyor
# Hannah Torres || Commercial horticulturist
# Nicholas Vega || Fashion designer
# Amy Robles || Therapist, horticultural
# Jonathan Chan || Associate Professor
# Jennifer Guerrero || Games developer
# Michelle Jenkins || Banker
# Ashley Munoz || Conference centre manager
# James Williams || Radio broadcast assistant

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from faker import Faker
import random
from datetime import datetime #For generating dates and times
#Don't forget to import the module to generate random numbers!
fake = Faker(['en_CA'])


#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
for _ in range(1000):
  addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""



  myPerson = (fake.name(), 
            fake.email(), 
            fake.address(), 
            fake.city(), 
            fake.province(), 
            fake.country(), 
            fake.phone_number(), 
            fake.bs(),
            fake.date_of_birth(),
            random.randint(999,2500),
            datetime.now(), 
            datetime.now(),
            fake.ipv4())
  
  myCursor.execute(addPersonQuery, myPerson)




  


myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

#Ideally, you will want to create a loop that will iterate 1000 times,
#Observe the example in the earlier code block showing the parameter tuple `myPerson`
#You can duplicate that inside your loop and replace those fields with calls to the appropriate faker provider method
#Execute your statement inside the loop,
#But, don't forget to commit and close your connection when you have finished!
myConnection.commit()
myConnection.close()
# Out:
# Streaming output truncated to the last 5000 lines.
#   '2021-02-23 15:30:36.488716',
#   '178.182.245.103'),
#  (644,
#   'Kristin Lowe',
#   'shawn88@yahoo.com',
#   '085 Aaron Villages\nJacksonmouth, BC E7C 8J4',
#   'Christopherfurt',
#   'Yukon Territory',
#   'Turkmenistan',
#   '337.504.6339',
#   'enable robust functionalities',
#   '2020-03-05',
#   1009,
#   '2021-02-23 15:30:36.489336',
#   '2021-02-23 15:30:36.489337',
#   '220.33.166.227'),
#  (645,
#   'James Gibbs',
#   'michaelaguilar@mclean.com',
#   '5627 Michael Groves Suite 889\nSotoburgh, YT T9N 9K6',
#   'Lake Kyleton',
#   'Northwest Territories',
#   'Turkey',
#   '203-457-9590 x713',
#   'engineer revolutionary synergies',
#   '1923-05-15',
#   1666,
#   '2021-02-23 15:30:36.490237',
#   '2021-02-23 15:30:36.490238',
#   '87.156.176.164'),
#  (646,
#   'Michelle Long',
#   'phillipslisa@hotmail.com',
#   '5107 Lopez Bridge Suite 272\nNorth Brittany, NU B8L 3M6',
#   'South Jeffreyville',
#   'New Brunswick',
#   'Saint Kitts and Nevis',
#   '(495) 627-7579',
#   'reinvent rich portals',
#   '1916-08-21',
#   1891,
#   '2021-02-23 15:30:36.491001',
#   '2021-02-23 15:30:36.491002',
#   '150.223.53.154'),
#  (647,
#   'Isaac Kennedy',
#   'crossmichael@velazquez-tran.com',
#   '885 Lin Stravenue Apt. 534\nHawkinsfurt, PE Y7X5T9',
#   'East Juanland',
#   'British Columbia',
#   'Sierra Leone',
#   '851.423.5886',
#   'target rich technologies',
#   '2013-06-07',
#   2271,
#   '2021-02-23 15:30:36.491944',
#   '2021-02-23 15:30:36.491944',
#   '13.194.223.29'),
#  (648,
#   'Gloria Fitzgerald',
#   'nicolemarshall@hotmail.com',
#   '77390 Craig Stravenue Suite 455\nRonaldtown, NS G5B1K1',
#   'New Stephaniemouth',
#   'Nova Scotia',
#   'Finland',
#   '844.688.3205',
#   'brand front-end paradigms',
#   '2004-12-25',
#   2230,
#   '2021-02-23 15:30:36.492663',
#   '2021-02-23 15:30:36.492664',
#   '187.161.17.126'),
#  (649,
#   'Eddie Vasquez',
#   'iray@watson.com',
#   '43921 Alexis Ville Suite 823\nJulieshire, YT T2T 1V3',
#   'East Nicole',
#   'Ontario',
#   'Guam',
#   '(800) 908-0701 x094',
#   'incentivize cross-media niches',
#   '1975-12-14',
#   2378,
#   '2021-02-23 15:30:36.493430',
#   '2021-02-23 15:30:36.493431',
#   '81.79.120.211'),
#  (650,
#   'Monica Estrada',
#   'tarcher@gutierrez.com',
#   '44040 Joshua Estates Suite 575\nPort Thomasberg, MB H4X9V1',
#   'Kennedyfurt',
#   'British Columbia',
#   'Puerto Rico',
#   '621-554-5723',
#   'cultivate value-added synergies',
#   '1929-11-30',
#   2125,
#   '2021-02-23 15:30:36.494356',
#   '2021-02-23 15:30:36.494358',
#   '64.224.180.159'),
#  (651,
#   'Annette Johnson',
#   'ericruiz@ayala.net',
#   '95212 Warren Brook\nLake Travisview, NL C3S1T4',
#   'New Robertland',
#   'British Columbia',
#   'United States Minor Outlying Islands',
#   '+1 (942) 018-7425',
#   'repurpose dot-com channels',
#   '1967-03-29',
#   2376,
#   '2021-02-23 15:30:36.495229',
#   '2021-02-23 15:30:36.495230',
#   '8.84.50.12'),
#  (652,
#   'David Anderson',
#   'vosborne@estrada.com',
#   '2744 Johnson Forge Apt. 539\nRichardsonhaven, AB B3P 2K7',
#   'Daniellemouth',
#   'British Columbia',
#   'Guinea-Bissau',
#   '272.660.7463',
#   'engage vertical schemas',
#   '1959-12-26',
#   2268,
#   '2021-02-23 15:30:36.496201',
#   '2021-02-23 15:30:36.496202',
#   '167.18.187.222'),
#  (653,
#   'Elizabeth Jones',
#   'josephjohnson@marshall.com',
#   '2958 Williams Plaza Suite 026\nGeraldfort, MB Y7M5T5',
#   'Sheristad',
#   'New Brunswick',
#   'Tuvalu',
#   '1 (502) 633-3923',
#   'embrace next-generation action-items',
#   '2003-11-16',
#   1632,
#   '2021-02-23 15:30:36.497054',
#   '2021-02-23 15:30:36.497055',
#   '43.44.49.55'),
#  (654,
#   'Emily Lin',
#   'scarpenter@jones.info',
#   '477 Steven Oval\nDominiqueville, AB B5Y7S8',
#   'South Claireville',
#   'Alberta',
#   'Moldova',
#   '1-116-199-6342',
#   'envisioneer visionary e-markets',
#   '2003-06-21',
#   1331,
#   '2021-02-23 15:30:36.497807',
#   '2021-02-23 15:30:36.497808',
#   '81.194.52.82'),
#  (655,
#   'Debbie Johnson',
#   'melissa76@hotmail.com',
#   '3610 Stone Ville Apt. 507\nLiborough, BC M9R5X3',
#   'Huberstad',
#   'Manitoba',
#   'Kazakhstan',
#   '267.989.4671',
#   'enhance robust synergies',
#   '2012-02-08',
#   2492,
#   '2021-02-23 15:30:36.498521',
#   '2021-02-23 15:30:36.498522',
#   '168.65.203.33'),
#  (656,
#   'Susan Barton',
#   'andrew00@sutton-callahan.biz',
#   '5118 Kim Ferry Apt. 808\nPort Christopher, SK G7T3C5',
#   'Lauraberg',
#   'Newfoundland and Labrador',
#   'Burundi',
#   '1 (193) 261-3414',
#   'integrate open-source initiatives',
#   '1971-06-19',
#   1608,
#   '2021-02-23 15:30:36.499319',
#   '2021-02-23 15:30:36.499319',
#   '15.251.82.20'),
#  (657,
#   'Melissa Marks',
#   'gabriella14@brown.com',
#   '39956 Julie Crest\nJosephland, YT P8H8T9',
#   'Lambertchester',
#   'Nova Scotia',
#   'Liberia',
#   '493.630.9605',
#   'grow interactive synergies',
#   '1939-12-21',
#   1341,
#   '2021-02-23 15:30:36.500215',
#   '2021-02-23 15:30:36.500216',
#   '125.218.17.116'),
#  (658,
#   'Michael Miller',
#   'camposolivia@sandoval.com',
#   '79703 Paul Green\nHensonside, PE S6M8L3',
#   'Stephensmouth',
#   'Nunavut',
#   "Cote d'Ivoire",
#   '(551) 649-6033',
#   'integrate rich models',
#   '2007-12-08',
#   1835,
#   '2021-02-23 15:30:36.501078',
#   '2021-02-23 15:30:36.501079',
#   '82.135.31.124'),
#  (659,
#   'Louis Manning',
#   'lcrawford@yahoo.com',
#   '72760 Victoria Estate Suite 941\nHorneborough, SK L2J1E8',
#   'Josephfurt',
#   'Manitoba',
#   'Mongolia',
#   '1-382-555-4383',
#   'grow plug-and-play bandwidth',
#   '1944-04-21',
#   2214,
#   '2021-02-23 15:30:36.501817',
#   '2021-02-23 15:30:36.501818',
#   '197.194.193.215'),
#  (660,
#   'James Stewart',
#   'ibailey@gmail.com',
#   '30122 Patrick Squares Apt. 900\nNorth Charles, ON L4A6R1',
#   'Garyborough',
#   'New Brunswick',
#   'Cameroon',
#   '(642) 984-7726',
#   'engage web-enabled vortals',
#   '2012-05-26',
#   1504,
#   '2021-02-23 15:30:36.502488',
#   '2021-02-23 15:30:36.502489',
#   '117.249.142.68'),
#  (661,
#   'Thomas Lambert',
#   'browningsandra@lee.com',
#   '5042 Matthew Fort Suite 692\nWest Joe, QC J4P4G2',
#   'Lake Dennisburgh',
#   'Newfoundland and Labrador',
#   'Greenland',
#   '+1 (188) 753-0152',
#   'synergize open-source metrics',
#   '1995-05-28',
#   2255,
#   '2021-02-23 15:30:36.503299',
#   '2021-02-23 15:30:36.503300',
#   '74.62.64.81'),
#  (662,
#   'John Lopez',
#   'alvarezmichael@hotmail.com',
#   '9582 Singleton Harbors Apt. 812\nPort Nancy, ON P8E 3C4',
#   'Jodymouth',
#   'New Brunswick',
#   'Chile',
#   '1-799-034-4842',
#   'enable global e-business',
#   '1954-01-21',
#   2465,
#   '2021-02-23 15:30:36.504041',
#   '2021-02-23 15:30:36.504042',
#   '52.89.202.212'),
#  (663,
#   'Joshua Hurley',
#   'andreafrank@hotmail.com',
#   '2723 Michael Drive Suite 470\nMeganhaven, NL E5P 7M3',
#   'Markburgh',
#   'Nunavut',
#   'Sweden',
#   '1 (269) 640-4289',
#   'visualize transparent methodologies',
#   '1959-06-23',
#   1887,
#   '2021-02-23 15:30:36.504851',
#   '2021-02-23 15:30:36.504852',
#   '211.120.158.33'),
#  (664,
#   'Jennifer Foster',
#   'mitchellcolleen@hotmail.com',
#   '7698 Campbell Glen Suite 658\nClintonmouth, BC G1G 5S7',
#   'New Scottchester',
#   'Nunavut',
#   'Seychelles',
#   '527-837-0652',
#   'scale B2C markets',
#   '2003-02-20',
#   1523,
#   '2021-02-23 15:30:36.505654',
#   '2021-02-23 15:30:36.505655',
#   '154.92.63.241'),
#  (665,
#   'Amy Johnson',
#   'angelasmith@yahoo.com',
#   '75490 Cohen Drive\nPort Hannahside, MB T1B2P4',
#   'East Ashleyside',
#   'Ontario',
#   'American Samoa',
#   '514.730.8868',
#   'e-enable proactive ROI',
#   '1922-10-14',
#   2089,
#   '2021-02-23 15:30:36.506447',
#   '2021-02-23 15:30:36.506448',
#   '24.207.11.80'),
#  (666,
#   'Christina Jimenez',
#   'salinasevan@sandoval.com',
#   '9220 Dominique View\nSouth Jamieborough, YT Y9K 2N2',
#   'Robinsonberg',
#   'Quebec',
#   'Angola',
#   '231.604.8272',
#   'grow proactive markets',
#   '1991-11-30',
#   1199,
#   '2021-02-23 15:30:36.507458',
#   '2021-02-23 15:30:36.507460',
#   '72.164.202.240'),
#  (667,
#   'Taylor Wong',
#   'shirley96@brooks-powers.net',
#   '7245 Campbell View Apt. 131\nJosephtown, QC T8B1R7',
#   'North Tyler',
#   'Nova Scotia',
#   'Togo',
#   '(211) 731-4286',
#   'synergize impactful systems',
#   '1924-05-27',
#   1054,
#   '2021-02-23 15:30:36.508312',
#   '2021-02-23 15:30:36.508313',
#   '104.189.216.152'),
#  (668,
#   'Christopher Mendoza',
#   'zsmith@peterson.net',
#   '65434 Gwendolyn Shoal Suite 885\nPort Monique, BC L5R 2L5',
#   'Port Patricia',
#   'Ontario',
#   'Afghanistan',
#   '905-933-2605 x256',
#   'optimize front-end portals',
#   '1969-09-28',
#   1299,
#   '2021-02-23 15:30:36.509125',
#   '2021-02-23 15:30:36.509126',
#   '168.224.62.198'),
#  (669,
#   'Amy Davis',
#   'arobinson@yahoo.com',
#   '54837 Carolyn Lakes\nLopezstad, NL C6V1S6',
#   'Bruceburgh',
#   'Saskatchewan',
#   'Macedonia',
#   '826-584-8661',
#   'engineer web-enabled networks',
#   '1985-01-17',
#   1235,
#   '2021-02-23 15:30:36.509895',
#   '2021-02-23 15:30:36.509896',
#   '140.134.99.211'),
#  (670,
#   'Kristopher Young',
#   'michael31@allen-fernandez.com',
#   '31661 Wood Road Apt. 582\nEast Trevor, QC C8E2M5',
#   'North Curtis',
#   'Nova Scotia',
#   'Pakistan',
#   '143 721 1094',
#   'generate ubiquitous initiatives',
#   '1962-09-21',
#   2368,
#   '2021-02-23 15:30:36.510742',
#   '2021-02-23 15:30:36.510743',
#   '218.15.18.65'),
#  (671,
#   'Kevin Castro',
#   'halejerry@hotmail.com',
#   '22340 Fox Inlet Apt. 559\nNew Gabrielview, NB M4X 5M4',
#   'Wendymouth',
#   'Nova Scotia',
#   'Vanuatu',
#   '596.100.9141',
#   'productize rich networks',
#   '1952-06-01',
#   1792,
#   '2021-02-23 15:30:36.511510',
#   '2021-02-23 15:30:36.511511',
#   '164.66.85.34'),
#  (672,
#   'Brandon Roberts',
#   'fmcguire@yahoo.com',
#   '550 White Shoal Suite 070\nMarkburgh, ON E9L3C9',
#   'Jefferyfort',
#   'Yukon Territory',
#   'Spain',
#   '(888) 816-2547',
#   'scale one-to-one solutions',
#   '1957-10-19',
#   1537,
#   '2021-02-23 15:30:36.512189',
#   '2021-02-23 15:30:36.512190',
#   '178.84.23.182'),
#  (673,
#   'Amanda Ortiz',
#   'kingthomas@hotmail.com',
#   '313 Roth Rest\nLeahmouth, NS G3M3A5',
#   'Lake Melissa',
#   'Ontario',
#   'Cyprus',
#   '960.887.2348',
#   'e-enable front-end architectures',
#   '1940-10-07',
#   1591,
#   '2021-02-23 15:30:36.512914',
#   '2021-02-23 15:30:36.512915',
#   '204.5.164.250'),
#  (674,
#   'Jeff Hanson',
#   'zhanson@hansen-henderson.com',
#   '986 Mark Row\nRobinville, PE K8E 2J9',
#   'Cliffordshire',
#   'Ontario',
#   'Moldova',
#   '255 865 3884',
#   'reinvent best-of-breed metrics',
#   '1907-09-02',
#   1713,
#   '2021-02-23 15:30:36.513730',
#   '2021-02-23 15:30:36.513731',
#   '65.71.168.94'),
#  (675,
#   'Patrick Green',
#   'richardsjulie@gmail.com',
#   '1546 Johnson Street\nEast James, BC E7L 4G9',
#   'Josephville',
#   'Nunavut',
#   'Peru',
#   '(322) 317-5946',
#   'whiteboard extensible paradigms',
#   '1975-04-21',
#   1371,
#   '2021-02-23 15:30:36.514486',
#   '2021-02-23 15:30:36.514487',
#   '97.247.232.4'),
#  (676,
#   'Melissa Silva',
#   'zmoreno@gonzales-lee.com',
#   '748 Jacobson Pass\nWalterstad, NT K9J 5E1',
#   'Port Stephanie',
#   'Ontario',
#   'Fiji',
#   '276 692 2158',
#   'e-enable out-of-the-box e-services',
#   '1905-03-14',
#   1916,
#   '2021-02-23 15:30:36.515342',
#   '2021-02-23 15:30:36.515343',
#   '193.227.21.161'),
#  (677,
#   'Kelly Jones',
#   'connor49@thomas-brown.org',
#   '75436 Marks Forks Suite 146\nNew Jack, PE R7Y 4T8',
#   'Port Jeremychester',
#   'Manitoba',
#   'Estonia',
#   '(695) 436-6243',
#   'harness visionary deliverables',
#   '1918-12-20',
#   1489,
#   '2021-02-23 15:30:36.516207',
#   '2021-02-23 15:30:36.516208',
#   '7.42.159.84'),
#  (678,
#   'Robert Grant',
#   'sowens@edwards-harper.com',
#   '27377 Thomas Freeway Apt. 470\nSouth Jacob, NB J1A2G3',
#   'South Jessicaton',
#   'Ontario',
#   'Nauru',
#   '320-014-6742 x035',
#   'synthesize plug-and-play functionalities',
#   '1992-01-12',
#   1041,
#   '2021-02-23 15:30:36.517085',
#   '2021-02-23 15:30:36.517086',
#   '18.205.4.42'),
#  (679,
#   'Brittany Lowery',
#   'mendozajoseph@hotmail.com',
#   '330 John Mountains Apt. 683\nPort Brettville, MB E6L7T7',
#   'South Wayne',
#   'Ontario',
#   'American Samoa',
#   '+1 (752) 223-5233',
#   'mesh mission-critical experiences',
#   '1955-08-24',
#   2219,
#   '2021-02-23 15:30:36.517816',
#   '2021-02-23 15:30:36.517817',
#   '33.85.132.40'),
#  (680,
#   'Caitlin Santos',
#   'victor85@ramirez-preston.biz',
#   '5317 Harrison Springs Apt. 965\nCunninghamchester, NT L6X 4A1',
#   'Leeton',
#   'Nova Scotia',
#   'Botswana',
#   '+1 (645) 764-4372',
#   'target mission-critical interfaces',
#   '2019-07-03',
#   2438,
#   '2021-02-23 15:30:36.518684',
#   '2021-02-23 15:30:36.518685',
#   '149.53.8.157'),
#  (681,
#   'John Knight',
#   'kshaw@hicks.com',
#   '706 Clark Lake\nLake Angela, ON V5P2A6',
#   'Ashleyfurt',
#   'Quebec',
#   'Romania',
#   '758-038-3749 x120',
#   'e-enable magnetic markets',
#   '1992-03-09',
#   2132,
#   '2021-02-23 15:30:36.519453',
#   '2021-02-23 15:30:36.519454',
#   '216.54.226.69'),
#  (682,
#   'Robert Boyd',
#   'eric94@hotmail.com',
#   '188 Morgan Flats\nSmallton, PE H4N3P7',
#   'North Andrewside',
#   'Quebec',
#   'Cook Islands',
#   '615-924-4517',
#   'strategize robust web services',
#   '1970-01-22',
#   1928,
#   '2021-02-23 15:30:36.520338',
#   '2021-02-23 15:30:36.520339',
#   '45.177.125.54'),
#  (683,
#   'Sheryl Hahn',
#   'michellelopez@yahoo.com',
#   '2893 Robin Locks\nNorth Crystalhaven, AB G5A8N7',
#   'Jasonburgh',
#   'Quebec',
#   'Rwanda',
#   '109-152-6912 x145',
#   'drive turn-key schemas',
#   '1941-01-01',
#   2278,
#   '2021-02-23 15:30:36.521084',
#   '2021-02-23 15:30:36.521085',
#   '43.125.84.73'),
#  (684,
#   'Brittany Wilson',
#   'htorres@warren.com',
#   '4721 Dominique Lights\nSouth Megan, NU T6H3K7',
#   'Nancychester',
#   'Northwest Territories',
#   'Mali',
#   '209-085-7672 x732',
#   'integrate cross-media functionalities',
#   '1970-11-10',
#   2416,
#   '2021-02-23 15:30:36.521858',
#   '2021-02-23 15:30:36.521859',
#   '157.25.38.81'),
#  (685,
#   'Eric Young',
#   'ronaldrobinson@adkins.com',
#   '4298 Monica Crescent Apt. 511\nJessicaville, YT E2E8L6',
#   'East Williamchester',
#   'New Brunswick',
#   'Argentina',
#   '584-946-0635 x708',
#   'engineer best-of-breed relationships',
#   '1973-06-28',
#   2430,
#   '2021-02-23 15:30:36.522897',
#   '2021-02-23 15:30:36.522898',
#   '37.87.51.208'),
#  (686,
#   'Steven Rosales',
#   'ewilliams@gmail.com',
#   '296 Thomas Village\nJohnsonview, SK N8K2N4',
#   'Mooretown',
#   'British Columbia',
#   'Myanmar',
#   '(275) 110-4579 x557',
#   'expedite world-class users',
#   '1946-08-01',
#   1954,
#   '2021-02-23 15:30:36.523612',
#   '2021-02-23 15:30:36.523613',
#   '7.219.184.147'),
#  (687,
#   'James Nelson',
#   'latoya10@yahoo.com',
#   '0291 Michael Via Suite 329\nRichardsonberg, NB G5R4L5',
#   'Lake Robin',
#   'New Brunswick',
#   'Cyprus',
#   '123.558.9930',
#   'aggregate one-to-one relationships',
#   '1988-07-24',
#   1729,
#   '2021-02-23 15:30:36.524272',
#   '2021-02-23 15:30:36.524273',
#   '34.94.214.249'),
#  (688,
#   'Catherine Bowers',
#   'stephanie82@hotmail.com',
#   '114 Maurice Spring Apt. 052\nMoralesstad, SK A3E6V1',
#   'East Janiceville',
#   'Ontario',
#   'Montenegro',
#   '+1 (482) 211-3779',
#   'morph real-time convergence',
#   '1947-08-13',
#   1479,
#   '2021-02-23 15:30:36.524961',
#   '2021-02-23 15:30:36.524962',
#   '134.238.170.206'),
#  (689,
#   'Lisa Williams DVM',
#   'carpenterkayla@woodard.com',
#   '1947 Marie Square Apt. 732\nEast Shellyland, BC C2H2V9',
#   'Jamesland',
#   'Manitoba',
#   'Cocos (Keeling) Islands',
#   '896-151-0950 x179',
#   'deploy strategic systems',
#   '1973-02-04',
#   2465,
#   '2021-02-23 15:30:36.525819',
#   '2021-02-23 15:30:36.525820',
#   '29.139.114.47'),
#  (690,
#   'Andrew Martinez',
#   'janetgilbert@sandoval.com',
#   '893 Donna Summit Apt. 168\nLake Sabrina, AB R6H9A2',
#   'Dayfurt',
#   'British Columbia',
#   'Guinea-Bissau',
#   '+1 (375) 056-5087',
#   'iterate customized functionalities',
#   '1984-11-23',
#   1334,
#   '2021-02-23 15:30:36.526816',
#   '2021-02-23 15:30:36.526817',
#   '96.72.83.33'),
#  (691,
#   'Justin Perez',
#   'randallrocha@gmail.com',
#   '68004 Sherry Terrace Suite 119\nLake Vanessamouth, MB K8A 6K9',
#   'East Gregory',
#   'Yukon Territory',
#   "Cote d'Ivoire",
#   '709 194 9649',
#   'implement real-time portals',
#   '1923-06-20',
#   2007,
#   '2021-02-23 15:30:36.527538',
#   '2021-02-23 15:30:36.527539',
#   '153.5.157.247'),
#  (692,
#   'Shannon Sampson',
#   'deanhart@hansen.com',
#   '27830 Brown Tunnel\nPort Matthew, YT J6A5M5',
#   'East Christianmouth',
#   'Nunavut',
#   'Bahrain',
#   '915-924-4372',
#   'generate end-to-end bandwidth',
#   '1989-03-22',
#   2415,
#   '2021-02-23 15:30:36.528352',
#   '2021-02-23 15:30:36.528353',
#   '152.232.203.124'),
#  (693,
#   'Joshua Smith',
#   'estein@becker-mckee.com',
#   '2513 Katrina Canyon Suite 335\nVegabury, QC G6B 2V6',
#   'Moralesstad',
#   'Ontario',
#   'Sudan',
#   '530 575 1538',
#   're-contextualize magnetic architectures',
#   '1935-02-24',
#   1707,
#   '2021-02-23 15:30:36.529241',
#   '2021-02-23 15:30:36.529242',
#   '148.135.37.186'),
#  (694,
#   'Seth Conrad',
#   'davilaeileen@cruz-neal.com',
#   '177 Kennedy Overpass Suite 943\nPort Alec, NS L6H 8T6',
#   'New Mark',
#   'Saskatchewan',
#   'Japan',
#   '922-714-0846 x771',
#   'morph front-end mindshare',
#   '1942-12-05',
#   1040,
#   '2021-02-23 15:30:36.530147',
#   '2021-02-23 15:30:36.530148',
#   '115.214.223.173'),
#  (695,
#   'Brittany Rogers',
#   'marklane@yahoo.com',
#   '0567 Shawn Extension Apt. 326\nAndreamouth, YT J5T2G5',
#   'Port Justin',
#   'Saskatchewan',
#   'Syrian Arab Republic',
#   '282-323-7524',
#   'syndicate out-of-the-box web services',
#   '2006-11-28',
#   2191,
#   '2021-02-23 15:30:36.530872',
#   '2021-02-23 15:30:36.530873',
#   '111.192.7.72'),
#  (696,
#   'Carlos Freeman',
#   'laurie64@gmail.com',
#   '56983 Shannon Cliff Apt. 721\nEast Theresa, NS V2H2Y8',
#   'Port Garyton',
#   'Newfoundland and Labrador',
#   'Antarctica (the territory South of 60 deg S)',
#   '1 (723) 857-4925',
#   'orchestrate open-source eyeballs',
#   '2014-06-20',
#   1898,
#   '2021-02-23 15:30:36.531550',
#   '2021-02-23 15:30:36.531551',
#   '84.207.146.228'),
#  (697,
#   'Vickie Sanchez',
#   'thompsonandrew@harrington-vasquez.biz',
#   '184 Morgan Flats Apt. 826\nEast Erikaside, MB P8M 9T1',
#   'East Olivia',
#   'British Columbia',
#   'Western Sahara',
#   '1-262-344-2073',
#   'architect vertical interfaces',
#   '1984-11-21',
#   1570,
#   '2021-02-23 15:30:36.532443',
#   '2021-02-23 15:30:36.532444',
#   '8.29.36.0'),
#  (698,
#   'Tina Wilson MD',
#   'joshuarobinson@smith-snyder.biz',
#   '69183 Anthony Wall\nEast Douglaschester, YT N9M 2E6',
#   'Phillipsmouth',
#   'New Brunswick',
#   'New Zealand',
#   '627.629.1636',
#   'engage intuitive initiatives',
#   '1945-08-14',
#   2350,
#   '2021-02-23 15:30:36.533332',
#   '2021-02-23 15:30:36.533333',
#   '66.101.82.191'),
#  (699,
#   'Maxwell Vasquez',
#   'howardsamantha@mitchell-campbell.biz',
#   '196 Brandi Lights\nWest Jeffberg, NU G4A 6X4',
#   'West Diane',
#   'British Columbia',
#   'Denmark',
#   '1-752-270-8854',
#   'disintermediate interactive architectures',
#   '1962-01-08',
#   1147,
#   '2021-02-23 15:30:36.534208',
#   '2021-02-23 15:30:36.534209',
#   '182.60.84.7'),
#  (700,
#   'Joe Knox',
#   'wilsonronald@hotmail.com',
#   '63724 Gonzalez Parkway\nFosterville, QC N4L 3X5',
#   'West Nicholasport',
#   'British Columbia',
#   'Jordan',
#   '(222) 035-7690',
#   'incentivize scalable e-commerce',
#   '2018-12-15',
#   1716,
#   '2021-02-23 15:30:36.534995',
#   '2021-02-23 15:30:36.534996',
#   '121.158.98.182'),
#  (701,
#   'Maria Sherman',
#   'pstone@wise.com',
#   '959 Clinton Crossroad\nWest Jennifer, NU J8E 6Y1',
#   'East Nancyton',
#   'Nunavut',
#   'Guadeloupe',
#   '1 (314) 386-6170',
#   'reinvent transparent synergies',
#   '1966-12-19',
#   1290,
#   '2021-02-23 15:30:36.535767',
#   '2021-02-23 15:30:36.535768',
#   '23.154.114.53'),
#  (702,
#   'Billy Curtis',
#   'amy73@hotmail.com',
#   '39442 Mary Street\nLake Kimberlyfort, QC P4L7X3',
#   'Heatherville',
#   'Quebec',
#   'Oman',
#   '476-051-5388',
#   'synthesize visionary e-tailers',
#   '1953-08-03',
#   2100,
#   '2021-02-23 15:30:36.536421',
#   '2021-02-23 15:30:36.536422',
#   '184.168.233.63'),
#  (703,
#   'Sara Munoz',
#   'simpsonnathaniel@gmail.com',
#   '524 Amy Ways Apt. 687\nBrianport, ON T4G8X2',
#   'Garciaberg',
#   'Prince Edward Island',
#   'Uruguay',
#   '406-079-2760 x374',
#   'monetize e-business experiences',
#   '1912-07-25',
#   1828,
#   '2021-02-23 15:30:36.537165',
#   '2021-02-23 15:30:36.537166',
#   '129.98.176.45'),
#  (704,
#   'Ryan Nelson',
#   'silvarussell@nguyen-castaneda.com',
#   '39876 Dale Well Apt. 442\nGranttown, PE B8X1P4',
#   'Matthewfort',
#   'Yukon Territory',
#   'Wallis and Futuna',
#   '464-653-8015 x167',
#   'engage global info-mediaries',
#   '1947-09-26',
#   2325,
#   '2021-02-23 15:30:36.538075',
#   '2021-02-23 15:30:36.538076',
#   '47.6.123.214'),
#  (705,
#   'Richard Miller',
#   'theodore11@donovan-cook.com',
#   '156 Barton Pass\nWest Karen, NB T4J9X8',
#   'West Richardfurt',
#   'Manitoba',
#   'Vanuatu',
#   '1-214-901-1975',
#   'morph efficient web-readiness',
#   '1964-11-29',
#   1026,
#   '2021-02-23 15:30:36.538899',
#   '2021-02-23 15:30:36.538900',
#   '174.142.210.47'),
#  (706,
#   'Frank Lewis',
#   'andre97@hall.com',
#   '23542 Miller Flats Apt. 573\nWarrenshire, NB K7B 3K6',
#   'Casestad',
#   'Manitoba',
#   'Lesotho',
#   '1-251-874-7031',
#   'deliver web-enabled metrics',
#   '1916-01-29',
#   1221,
#   '2021-02-23 15:30:36.539851',
#   '2021-02-23 15:30:36.539852',
#   '98.222.216.125'),
#  (707,
#   'Jamie Phillips',
#   'patrick45@gmail.com',
#   '71145 Chris Center Apt. 928\nNew Robert, PE A5R2Y3',
#   'West Michelle',
#   'Nova Scotia',
#   'Bermuda',
#   '(654) 415-4352',
#   'strategize frictionless architectures',
#   '1954-08-02',
#   1387,
#   '2021-02-23 15:30:36.540510',
#   '2021-02-23 15:30:36.540511',
#   '72.96.74.186'),
#  (708,
#   'Brianna Hunt',
#   'lrios@gmail.com',
#   '90157 Dyer Square\nDevonmouth, AB J7V1T7',
#   'Brianton',
#   'Newfoundland and Labrador',
#   'Madagascar',
#   '(118) 182-2103 x412',
#   'synthesize cross-platform methodologies',
#   '1939-06-17',
#   2092,
#   '2021-02-23 15:30:36.541197',
#   '2021-02-23 15:30:36.541199',
#   '165.97.178.117'),
#  (709,
#   'James Lewis',
#   'pcurry@gmail.com',
#   '8779 Lawrence Knoll\nNew Jose, SK X8M6M3',
#   'Robinsontown',
#   'Saskatchewan',
#   'Cuba',
#   '(843) 367-6928 x480',
#   'transition integrated channels',
#   '1905-08-19',
#   1132,
#   '2021-02-23 15:30:36.541916',
#   '2021-02-23 15:30:36.541917',
#   '146.224.194.77'),
#  (710,
#   'Samuel Miller',
#   'davidwyatt@merritt.org',
#   '6192 Nicole Haven Apt. 173\nNathanview, NS M6X8Y7',
#   'Lake Mark',
#   'Northwest Territories',
#   'Netherlands Antilles',
#   '(473) 234-0026 x592',
#   'integrate clicks-and-mortar supply-chains',
#   '2014-02-03',
#   2460,
#   '2021-02-23 15:30:36.542871',
#   '2021-02-23 15:30:36.542872',
#   '194.105.33.230'),
#  (711,
#   'William Cannon',
#   'torresjoshua@bullock.com',
#   '503 Jessica Gateway Suite 718\nWest Lonnieton, ON G1Y 8R3',
#   'Fleminghaven',
#   'Nunavut',
#   'Marshall Islands',
#   '265.374.1251',
#   'whiteboard next-generation systems',
#   '1997-09-01',
#   1358,
#   '2021-02-23 15:30:36.543712',
#   '2021-02-23 15:30:36.543713',
#   '94.57.164.59'),
#  (712,
#   'Luke Estes',
#   'jill09@west.com',
#   '511 Beth Gardens\nSouth Geraldport, ON S5M2T6',
#   'Lake Lisa',
#   'Ontario',
#   'Estonia',
#   '341-117-8230',
#   'morph customized paradigms',
#   '1943-07-04',
#   2377,
#   '2021-02-23 15:30:36.544604',
#   '2021-02-23 15:30:36.544605',
#   '145.143.73.39'),
#  (713,
#   'Sophia Moore',
#   'mcclurerobert@woodard-martinez.info',
#   '9605 Watts Islands Apt. 741\nMurphyton, AB H8Y8X7',
#   'Johnsonmouth',
#   'New Brunswick',
#   'Germany',
#   '+1 (405) 444-1616',
#   'implement seamless e-markets',
#   '1998-10-30',
#   1705,
#   '2021-02-23 15:30:36.545559',
#   '2021-02-23 15:30:36.545560',
#   '109.10.29.57'),
#  (714,
#   'Peter Reyes',
#   'qmcintyre@galloway.com',
#   '1855 Eric Island Suite 954\nNorth Rachelberg, NU Y3J6C3',
#   'North Ianton',
#   'Northwest Territories',
#   'Antigua and Barbuda',
#   '(279) 586-9072 x545',
#   'scale e-business info-mediaries',
#   '1989-05-16',
#   1973,
#   '2021-02-23 15:30:36.546340',
#   '2021-02-23 15:30:36.546341',
#   '120.18.246.155'),
#  (715,
#   'Elizabeth Johnson',
#   'zjones@griffin.com',
#   '79831 Woodward Pass\nNicolehaven, NB Y9E 6K3',
#   'Port Eugenechester',
#   'Manitoba',
#   'Georgia',
#   '215 552 9518',
#   'streamline strategic partnerships',
#   '1919-01-01',
#   2405,
#   '2021-02-23 15:30:36.547265',
#   '2021-02-23 15:30:36.547266',
#   '114.68.38.48'),
#  (716,
#   'Yolanda Gomez',
#   'tdavis@gmail.com',
#   '735 Boyd Terrace Apt. 422\nEast Drew, PE E5L 9T3',
#   'East Ashley',
#   'British Columbia',
#   'Mongolia',
#   '994.793.9470',
#   'enhance web-enabled models',
#   '2006-11-01',
#   1337,
#   '2021-02-23 15:30:36.547979',
#   '2021-02-23 15:30:36.547980',
#   '209.245.10.49'),
#  (717,
#   'Adam Rose',
#   'jessica89@hotmail.com',
#   '1488 Watts Extension\nWest Priscillaberg, PE X1V2H3',
#   'New Amyview',
#   'Nunavut',
#   'Marshall Islands',
#   '1-178-122-0514',
#   'grow value-added interfaces',
#   '1909-02-01',
#   2254,
#   '2021-02-23 15:30:36.548647',
#   '2021-02-23 15:30:36.548648',
#   '217.77.115.159'),
#  (718,
#   'Christian Werner',
#   'hannah71@white-dunn.org',
#   '416 Heather Underpass\nStaceyhaven, QC N8Y 4X6',
#   'East Ellen',
#   'Nunavut',
#   'Turks and Caicos Islands',
#   '985-290-6292 x647',
#   'transform efficient web-readiness',
#   '1977-06-11',
#   2489,
#   '2021-02-23 15:30:36.549451',
#   '2021-02-23 15:30:36.549455',
#   '18.53.129.37'),
#  (719,
#   'Mr. Timothy Daniels',
#   'calvin79@gmail.com',
#   '844 Herrera Freeway\nGaryburgh, NB X5P 9K1',
#   'Thomaschester',
#   'Newfoundland and Labrador',
#   'Zambia',
#   '+1 (389) 136-4831',
#   'aggregate leading-edge deliverables',
#   '1918-02-03',
#   2041,
#   '2021-02-23 15:30:36.550134',
#   '2021-02-23 15:30:36.550135',
#   '176.82.178.217'),
#  (720,
#   'Jamie Morris',
#   'matthew99@gmail.com',
#   '7489 Jamie Mews Suite 762\nSouth Breannafort, AB X6M 4L7',
#   'Lake Elizabeth',
#   'Saskatchewan',
#   'Kyrgyz Republic',
#   '653.110.4012',
#   'disintermediate strategic bandwidth',
#   '1984-07-26',
#   2080,
#   '2021-02-23 15:30:36.550790',
#   '2021-02-23 15:30:36.550791',
#   '205.71.158.164'),
#  (721,
#   'Tiffany Chambers',
#   'nbell@austin-thompson.info',
#   '8928 Linda Locks Apt. 070\nAngelaborough, NB K9B2J6',
#   'Frankberg',
#   'Prince Edward Island',
#   'Bahamas',
#   '1 (698) 230-3547',
#   'generate dot-com eyeballs',
#   '1920-11-20',
#   1120,
#   '2021-02-23 15:30:36.552162',
#   '2021-02-23 15:30:36.552163',
#   '99.152.90.63'),
#  (722,
#   'Brittany Carson MD',
#   'jennifersingleton@hotmail.com',
#   '08995 Kathleen Walks Apt. 732\nSouth Tracy, ON R7L5X6',
#   'Greentown',
#   'Quebec',
#   'Guam',
#   '1-854-475-7712',
#   'implement wireless paradigms',
#   '2002-05-04',
#   1790,
#   '2021-02-23 15:30:36.553070',
#   '2021-02-23 15:30:36.553071',
#   '7.112.30.214'),
#  (723,
#   'Christopher Wallace',
#   'delgadosusan@yahoo.com',
#   '702 Martin Ridges Suite 317\nEast Tiffanyfurt, QC P1S 3T7',
#   'West Catherineberg',
#   'New Brunswick',
#   'Yemen',
#   '+1 (798) 861-1149',
#   'scale magnetic architectures',
#   '1963-02-12',
#   1150,
#   '2021-02-23 15:30:36.553895',
#   '2021-02-23 15:30:36.553896',
#   '153.106.113.208'),
#  (724,
#   'Daniel Lee',
#   'markmoran@yahoo.com',
#   '390 Alvarado Stream\nMurphyside, NB N7T1S6',
#   'Kellimouth',
#   'Yukon Territory',
#   'Netherlands',
#   '460-109-8485 x565',
#   'whiteboard synergistic functionalities',
#   '2020-03-21',
#   1120,
#   '2021-02-23 15:30:36.554711',
#   '2021-02-23 15:30:36.554712',
#   '209.23.72.35'),
#  (725,
#   'Joseph Foster',
#   'chernandez@hotmail.com',
#   '4262 Ann Trail Apt. 890\nSouth Bradley, NT R7L4M5',
#   'West Taraview',
#   'New Brunswick',
#   'Western Sahara',
#   '+1 (293) 043-0256',
#   'architect distributed info-mediaries',
#   '1967-10-25',
#   1606,
#   '2021-02-23 15:30:36.555534',
#   '2021-02-23 15:30:36.555535',
#   '189.168.188.160'),
#  (726,
#   'Carolyn Johnson',
#   'wilsonthomas@hill-ross.biz',
#   '7391 Francisco Green Suite 320\nKevinborough, MB K4E 4H9',
#   'Woodsside',
#   'Newfoundland and Labrador',
#   'Tunisia',
#   '(548) 836-2565 x948',
#   'incubate extensible eyeballs',
#   '1984-05-28',
#   2350,
#   '2021-02-23 15:30:36.556555',
#   '2021-02-23 15:30:36.556556',
#   '33.120.218.150'),
#  (727,
#   'Brett Carr',
#   'sabrinaroberts@wright.net',
#   '09990 Mills Landing Apt. 077\nNorth Julie, NL X9T7A8',
#   'New Natalie',
#   'Quebec',
#   'Guinea',
#   '159 184 7908',
#   'integrate B2C technologies',
#   '1993-08-06',
#   2058,
#   '2021-02-23 15:30:36.557460',
#   '2021-02-23 15:30:36.557461',
#   '31.249.226.134'),
#  (728,
#   'Kimberly Gentry',
#   'james53@yahoo.com',
#   '8043 Weiss Fords\nSouth Brendabury, AB S5J9B9',
#   'Chavezside',
#   'Ontario',
#   'Bolivia',
#   '+1 (712) 142-2507',
#   'benchmark rich ROI',
#   '1940-08-10',
#   1165,
#   '2021-02-23 15:30:36.558161',
#   '2021-02-23 15:30:36.558162',
#   '105.3.230.62'),
#  (729,
#   'Miss Dana Chapman',
#   'vaughndaniel@yahoo.com',
#   '37568 Bobby Common\nBillystad, ON N3N4G2',
#   'Smithton',
#   'Ontario',
#   'South Africa',
#   '+1 (938) 567-5151',
#   'morph sticky communities',
#   '2017-05-13',
#   2004,
#   '2021-02-23 15:30:36.558926',
#   '2021-02-23 15:30:36.558927',
#   '3.72.199.100'),
#  (730,
#   'Theresa Hansen',
#   'bridgesdaniel@porter-morales.com',
#   '4726 Hull Ramp Suite 607\nNew Cole, NS R5J5K7',
#   'North Latasha',
#   'New Brunswick',
#   'Solomon Islands',
#   '1 (124) 396-0128',
#   'cultivate collaborative experiences',
#   '1945-09-19',
#   1862,
#   '2021-02-23 15:30:36.559875',
#   '2021-02-23 15:30:36.559876',
#   '216.32.9.211'),
#  (731,
#   'Katrina Friedman',
#   'jessicalong@horton.com',
#   '8255 Shannon Avenue\nNew Regina, NS R4X 2K7',
#   'Williamsonbury',
#   'Saskatchewan',
#   'French Polynesia',
#   '(698) 955-9219 x558',
#   'cultivate collaborative e-markets',
#   '2012-10-25',
#   2346,
#   '2021-02-23 15:30:36.560736',
#   '2021-02-23 15:30:36.560737',
#   '129.3.244.61'),
#  (732,
#   'Shelley Walker',
#   'seanburke@richardson.org',
#   '1106 Robert Garden Suite 327\nNorth Joe, PE N6E9P1',
#   'Lake Thomasville',
#   'British Columbia',
#   'Mongolia',
#   '210-318-3983',
#   'enhance ubiquitous e-services',
#   '1908-04-20',
#   1063,
#   '2021-02-23 15:30:36.561760',
#   '2021-02-23 15:30:36.561761',
#   '75.107.224.201'),
#  (733,
#   'Christopher Meyer',
#   'dawsonamber@wilkerson.info',
#   '140 Sutton Parkway Apt. 523\nPort William, NL C3V5B9',
#   'South Shawnafurt',
#   'Yukon Territory',
#   'Chile',
#   '278.918.9724',
#   'harness value-added initiatives',
#   '1977-05-06',
#   1609,
#   '2021-02-23 15:30:36.563122',
#   '2021-02-23 15:30:36.563123',
#   '68.61.201.247'),
#  (734,
#   'Kevin Bishop',
#   'thomas02@pitts.com',
#   '453 Gonzalez Keys Suite 858\nJohnsonstad, NL K6V 6N4',
#   'Andrewsberg',
#   'Ontario',
#   'Gibraltar',
#   '749 359 2685',
#   'architect collaborative e-services',
#   '1907-05-23',
#   1339,
#   '2021-02-23 15:30:36.564061',
#   '2021-02-23 15:30:36.564062',
#   '223.249.206.2'),
#  (735,
#   'Joseph Wallace',
#   'danielleblackburn@hawkins.info',
#   '25861 Becky Turnpike Suite 766\nSouth Amandaport, YT H5C 9A2',
#   'Olsonborough',
#   'Prince Edward Island',
#   'Wallis and Futuna',
#   '138-192-1651 x387',
#   'grow customized web services',
#   '1975-04-19',
#   2080,
#   '2021-02-23 15:30:36.565143',
#   '2021-02-23 15:30:36.565144',
#   '185.48.211.111'),
#  (736,
#   'Dorothy Anderson',
#   'ocook@gmail.com',
#   '5189 Donald Loaf\nRichmondbury, BC S6R 5J2',
#   'Harrisside',
#   'Quebec',
#   'Bouvet Island (Bouvetoya)',
#   '+1 (407) 863-7391',
#   'enhance B2B communities',
#   '1952-12-22',
#   1251,
#   '2021-02-23 15:30:36.565911',
#   '2021-02-23 15:30:36.565912',
#   '137.235.226.170'),
#  (737,
#   'Jordan Cobb',
#   'laurenhall@wilson.com',
#   '01040 Castillo Rapids\nRamosside, NU C6G4G6',
#   'Turnerstad',
#   'Newfoundland and Labrador',
#   'United States Virgin Islands',
#   '(267) 300-6917 x043',
#   'integrate value-added mindshare',
#   '1953-04-06',
#   1934,
#   '2021-02-23 15:30:36.566859',
#   '2021-02-23 15:30:36.566860',
#   '14.203.205.170'),
#  (738,
#   'Gary Ford',
#   'fgarcia@byrd.com',
#   '31769 Perez Center Suite 206\nSouth Timothy, ON L2M4N2',
#   'Lake Melissashire',
#   'Saskatchewan',
#   'Mauritius',
#   '653-451-1982 x623',
#   'drive extensible portals',
#   '1998-12-18',
#   1934,
#   '2021-02-23 15:30:36.567858',
#   '2021-02-23 15:30:36.567859',
#   '217.155.32.56'),
#  (739,
#   'Nicholas Simmons',
#   'ebrown@gmail.com',
#   '8422 Weeks Wells Apt. 336\nAnthonyfurt, YT M3E 4K5',
#   'Newmanville',
#   'Nova Scotia',
#   'Gibraltar',
#   '(632) 646-3909',
#   'iterate visionary markets',
#   '1927-01-20',
#   1250,
#   '2021-02-23 15:30:36.568667',
#   '2021-02-23 15:30:36.568668',
#   '116.32.83.82'),
#  (740,
#   'Yvette Myers',
#   'kirkgillespie@hotmail.com',
#   '6368 Debbie Parks Suite 871\nSouth Danielle, AB A2B 9T8',
#   'West Pamelafort',
#   'Ontario',
#   'Bouvet Island (Bouvetoya)',
#   '(299) 528-1446 x507',
#   'strategize e-business deliverables',
#   '1955-02-01',
#   2244,
#   '2021-02-23 15:30:36.569445',
#   '2021-02-23 15:30:36.569446',
#   '189.8.84.201'),
#  (741,
#   'Wanda Howe',
#   'kimberlyphillips@hotmail.com',
#   '3467 Angela Summit Apt. 314\nSouth Louis, AB J9E 8X9',
#   'South Alexisburgh',
#   'Saskatchewan',
#   'Congo',
#   '168.085.6784',
#   'cultivate clicks-and-mortar bandwidth',
#   '1993-03-16',
#   2421,
#   '2021-02-23 15:30:36.570209',
#   '2021-02-23 15:30:36.570210',
#   '51.153.244.36'),
#  (742,
#   'Matthew Mcmahon',
#   'mgonzalez@collier.com',
#   '126 Hansen Glen Apt. 370\nNorth Charleneside, ON C5A 8J4',
#   'Teresatown',
#   'Nova Scotia',
#   'Sri Lanka',
#   '559.789.0230',
#   'innovate dynamic web services',
#   '1977-10-25',
#   1963,
#   '2021-02-23 15:30:36.571066',
#   '2021-02-23 15:30:36.571068',
#   '25.58.39.154'),
#  (743,
#   'Jennifer Stephenson',
#   'lorisullivan@jacobs.com',
#   '40971 Peterson Trafficway Suite 610\nTroychester, NS N6G 5E3',
#   'New Sheenamouth',
#   'Manitoba',
#   'Jersey',
#   '139-672-3494 x706',
#   'enhance interactive solutions',
#   '2019-06-26',
#   1507,
#   '2021-02-23 15:30:36.571969',
#   '2021-02-23 15:30:36.571970',
#   '198.190.190.85'),
#  (744,
#   'Sarah Edwards',
#   'steve11@gmail.com',
#   '84886 Brown Corner\nPort Williamstad, NU X6V9B4',
#   'Port Hollyburgh',
#   'Nova Scotia',
#   'Falkland Islands (Malvinas)',
#   '225-761-6068 x622',
#   'monetize compelling web-readiness',
#   '1931-03-27',
#   1658,
#   '2021-02-23 15:30:36.572668',
#   '2021-02-23 15:30:36.572669',
#   '108.165.251.1'),
#  (745,
#   'Christina Henderson',
#   'benjaminapril@yahoo.com',
#   '9497 Hubbard Estates Apt. 515\nSouth Matthew, SK B5C 5X7',
#   'North Jamietown',
#   'Quebec',
#   'Poland',
#   '798-694-5534 x008',
#   'reinvent collaborative ROI',
#   '1946-10-29',
#   1451,
#   '2021-02-23 15:30:36.573455',
#   '2021-02-23 15:30:36.573456',
#   '163.162.200.108'),
#  (746,
#   'Justin Morris',
#   'kberger@cervantes-hart.com',
#   '157 Vargas Via\nDerekborough, YT S3E 8N5',
#   'Patriciaview',
#   'Yukon Territory',
#   'Turks and Caicos Islands',
#   '(229) 778-0728',
#   'embrace viral web services',
#   '1969-04-16',
#   1791,
#   '2021-02-23 15:30:36.574305',
#   '2021-02-23 15:30:36.574306',
#   '96.119.207.25'),
#  (747,
#   'Andrea Terry',
#   'michaeljuarez@hotmail.com',
#   '4544 Adam Valley\nStewartfort, YT T6S 1B1',
#   'Lake Jennabury',
#   'Alberta',
#   'Guyana',
#   '625 103 9322',
#   'embrace clicks-and-mortar methodologies',
#   '1929-06-10',
#   2006,
#   '2021-02-23 15:30:36.575094',
#   '2021-02-23 15:30:36.575095',
#   '47.120.230.133'),
#  (748,
#   'Frank Arnold',
#   'samuelross@campbell-morrison.biz',
#   '797 Katherine Summit Suite 253\nWest Joseph, BC N8X 6Y4',
#   'Susantown',
#   'Northwest Territories',
#   'Pakistan',
#   '810-480-6776',
#   're-intermediate customized web services',
#   '1915-10-09',
#   2177,
#   '2021-02-23 15:30:36.576007',
#   '2021-02-23 15:30:36.576008',
#   '39.60.152.123'),
#  (749,
#   'Jamie Ross',
#   'gbeck@wolfe.com',
#   '6708 Kyle Terrace\nNew Rebeccaport, NT S7Y 6P4',
#   'South Traceymouth',
#   'Nova Scotia',
#   'Hungary',
#   '1 (594) 854-5864',
#   'maximize magnetic channels',
#   '1940-02-19',
#   1557,
#   '2021-02-23 15:30:36.576795',
#   '2021-02-23 15:30:36.576796',
#   '88.75.52.178'),
#  (750,
#   'Anthony Smith',
#   'heather45@yahoo.com',
#   '7665 Higgins Ports\nPort Elijah, BC C1Y 4L2',
#   'Port Christopherside',
#   'Saskatchewan',
#   'Bahrain',
#   '495 623 2094',
#   'e-enable web-enabled models',
#   '1934-04-26',
#   2061,
#   '2021-02-23 15:30:36.577477',
#   '2021-02-23 15:30:36.577478',
#   '94.22.40.223'),
#  (751,
#   'Beth Lopez',
#   'foxsharon@mills.info',
#   '85789 Adam Drive Apt. 333\nLake Brenda, NT B8L 2X3',
#   'North Victorport',
#   'Northwest Territories',
#   'Guyana',
#   '213.040.3638',
#   'deploy viral relationships',
#   '1917-08-30',
#   1277,
#   '2021-02-23 15:30:36.578295',
#   '2021-02-23 15:30:36.578296',
#   '76.90.37.92'),
#  (752,
#   'Jennifer Olson',
#   'edward84@bryan.com',
#   '8342 John Courts Apt. 008\nBryanthaven, NB P3R 7Y1',
#   'East Lindamouth',
#   'Yukon Territory',
#   'Reunion',
#   '1-221-562-6855',
#   'iterate dot-com vortals',
#   '1922-05-07',
#   1654,
#   '2021-02-23 15:30:36.579252',
#   '2021-02-23 15:30:36.579253',
#   '131.62.97.243'),
#  (753,
#   'Deanna Dawson',
#   'kristinastevenson@meyers.com',
#   '32047 Sandra Ranch\nShannonfort, NT P8C8V2',
#   'New Thomas',
#   'Nunavut',
#   'Equatorial Guinea',
#   '124-174-9057',
#   'strategize world-class channels',
#   '2021-02-08',
#   1249,
#   '2021-02-23 15:30:36.580215',
#   '2021-02-23 15:30:36.580216',
#   '70.246.19.252'),
#  (754,
#   'James Hernandez',
#   'michaelpayne@mahoney-wilson.com',
#   '6972 Yang Rapid Apt. 511\nBrianport, MB H3P 8V3',
#   'Susanville',
#   'New Brunswick',
#   'Isle of Man',
#   '+1 (949) 191-5210',
#   'strategize next-generation e-markets',
#   '1920-08-15',
#   2454,
#   '2021-02-23 15:30:36.581133',
#   '2021-02-23 15:30:36.581134',
#   '152.187.249.18'),
#  (755,
#   'Haley Hebert',
#   'cynthia25@gmail.com',
#   '3081 Andrea Freeway Apt. 368\nWest Jorgeside, ON A3M1S7',
#   'Michaelmouth',
#   'Northwest Territories',
#   'Cook Islands',
#   '544 313 6969',
#   'engineer cutting-edge applications',
#   '1954-07-08',
#   1275,
#   '2021-02-23 15:30:36.581847',
#   '2021-02-23 15:30:36.581848',
#   '131.146.111.226'),
#  (756,
#   'Melanie Robinson',
#   'hcummings@dean-nguyen.com',
#   '058 Copeland Tunnel Apt. 860\nBradyton, NL T4H 8J4',
#   'Lake Edwardberg',
#   'Yukon Territory',
#   'Iraq',
#   '+1 (587) 092-6245',
#   'innovate visionary info-mediaries',
#   '1919-03-02',
#   1837,
#   '2021-02-23 15:30:36.582777',
#   '2021-02-23 15:30:36.582778',
#   '131.94.243.62'),
#  (757,
#   'Brooke Jarvis',
#   'donaldperez@hotmail.com',
#   '98312 Moreno Path Apt. 441\nKaylashire, SK R3P9H3',
#   'North David',
#   'Ontario',
#   'Cocos (Keeling) Islands',
#   '779-810-7756',
#   'revolutionize proactive e-business',
#   '1988-02-21',
#   1593,
#   '2021-02-23 15:30:36.583555',
#   '2021-02-23 15:30:36.583556',
#   '148.239.129.50'),
#  (758,
#   'Jennifer Moore',
#   'kyle87@hotmail.com',
#   '35153 Mack Rue\nLukeview, SK B8C 3C5',
#   'New Aaronland',
#   'Newfoundland and Labrador',
#   'Bhutan',
#   '531 059 4264',
#   'maximize holistic info-mediaries',
#   '1933-02-08',
#   2354,
#   '2021-02-23 15:30:36.584219',
#   '2021-02-23 15:30:36.584220',
#   '8.140.190.193'),
#  (759,
#   'Dillon Tate',
#   'afields@ramos.org',
#   '78435 Juan Harbor\nWilliamsmouth, AB J1X 6A6',
#   'Lake Carolynside',
#   'Alberta',
#   'Maldives',
#   '(311) 139-8078',
#   'e-enable best-of-breed metrics',
#   '1982-10-27',
#   1719,
#   '2021-02-23 15:30:36.585010',
#   '2021-02-23 15:30:36.585011',
#   '220.79.55.142'),
#  (760,
#   'Samantha Marshall',
#   'jennifer64@phillips-walker.com',
#   '765 Carlos Extension\nWest Donald, MB C9T5A2',
#   'North Stephentown',
#   'Nova Scotia',
#   'Chad',
#   '1 (451) 080-4107',
#   'visualize holistic architectures',
#   '1922-05-07',
#   1559,
#   '2021-02-23 15:30:36.585842',
#   '2021-02-23 15:30:36.585843',
#   '24.132.144.58'),
#  (761,
#   'Sarah Johnson',
#   'jason69@austin.com',
#   '029 Frank Turnpike Suite 477\nWagnerside, BC S5K9Y8',
#   'Hardyville',
#   'New Brunswick',
#   'Poland',
#   '1-839-981-1216',
#   'drive 24/7 vortals',
#   '1928-10-25',
#   2139,
#   '2021-02-23 15:30:36.586833',
#   '2021-02-23 15:30:36.586834',
#   '92.217.55.141'),
#  (762,
#   'Michelle Fisher',
#   'tcunningham@hotmail.com',
#   '70303 Mario Shores\nRuthland, BC C5B3E6',
#   'New Shannonton',
#   'Prince Edward Island',
#   'Qatar',
#   '686-108-4415 x044',
#   'leverage world-class relationships',
#   '1940-09-04',
#   1978,
#   '2021-02-23 15:30:36.587511',
#   '2021-02-23 15:30:36.587512',
#   '45.253.22.166'),
#  (763,
#   'Elizabeth Mckay',
#   'pdelgado@hotmail.com',
#   '09989 David Islands Apt. 649\nBlackberg, YT V8A8M1',
#   'Lake Donnaville',
#   'Alberta',
#   'French Polynesia',
#   '868.545.4993',
#   'monetize cross-platform metrics',
#   '2005-03-05',
#   2342,
#   '2021-02-23 15:30:36.588214',
#   '2021-02-23 15:30:36.588215',
#   '68.33.89.249'),
#  (764,
#   'Karen Miller',
#   'cgamble@yahoo.com',
#   '537 Ramirez Lodge\nWilliamshire, YT V5L3L8',
#   'Debbiechester',
#   'Quebec',
#   'Congo',
#   '(446) 600-3968 x514',
#   'visualize granular experiences',
#   '1958-05-08',
#   1457,
#   '2021-02-23 15:30:36.588957',
#   '2021-02-23 15:30:36.588958',
#   '150.94.118.114'),
#  (765,
#   'Desiree Burnett',
#   'arodriguez@mejia-carson.info',
#   '86907 Julie Passage Suite 024\nPort Michael, NS T9L4N6',
#   'Courtneymouth',
#   'Newfoundland and Labrador',
#   'Turkmenistan',
#   '987-082-1248 x812',
#   'deploy customized schemas',
#   '1910-01-13',
#   2343,
#   '2021-02-23 15:30:36.589829',
#   '2021-02-23 15:30:36.589830',
#   '82.83.41.55'),
#  (766,
#   'Jimmy Dominguez',
#   'collinsbenjamin@gmail.com',
#   '5081 Lee Isle\nWest Katherineland, SK L4M3V9',
#   'Lake Katherineborough',
#   'Alberta',
#   'United States of America',
#   '559.067.4208',
#   'deliver leading-edge solutions',
#   '2015-11-11',
#   1531,
#   '2021-02-23 15:30:36.590593',
#   '2021-02-23 15:30:36.590594',
#   '95.117.121.152'),
#  (767,
#   'John Allison',
#   'melody02@hotmail.com',
#   '310 White Creek\nSouth Jasmineside, QC L6Y2Y4',
#   'New Suzanne',
#   'Newfoundland and Labrador',
#   'Comoros',
#   '(536) 729-0310',
#   'reinvent granular architectures',
#   '1968-06-01',
#   1070,
#   '2021-02-23 15:30:36.591262',
#   '2021-02-23 15:30:36.591263',
#   '217.163.207.142'),
#  (768,
#   'Lisa Webb',
#   'brittneyscott@yahoo.com',
#   '2892 Crystal Lane\nWilliamsberg, SK K9C2N7',
#   'Lake Steven',
#   'Nova Scotia',
#   'Malaysia',
#   '(704) 001-0677',
#   'reinvent sticky paradigms',
#   '1982-06-05',
#   1431,
#   '2021-02-23 15:30:36.591998',
#   '2021-02-23 15:30:36.591999',
#   '32.36.5.80'),
#  (769,
#   'Caleb Chan',
#   'james54@hall-johnson.com',
#   '797 Jaime Run Apt. 412\nWillisberg, NB A7P 2M3',
#   'Wilsonview',
#   'Nunavut',
#   'Maldives',
#   '472 462 0269',
#   'monetize transparent convergence',
#   '1951-11-02',
#   1485,
#   '2021-02-23 15:30:36.592861',
#   '2021-02-23 15:30:36.592862',
#   '68.34.135.233'),
#  (770,
#   'Jesse Gross',
#   'williamyork@hotmail.com',
#   '39848 Walker Route\nWest Christopherchester, QC X7C5V1',
#   'South Eric',
#   'Nova Scotia',
#   'Mauritania',
#   '576-400-9886 x918',
#   'engineer visionary vortals',
#   '1988-11-01',
#   2459,
#   '2021-02-23 15:30:36.593601',
#   '2021-02-23 15:30:36.593602',
#   '111.164.237.225'),
#  (771,
#   'Timothy Turner',
#   'larry05@wyatt-chambers.com',
#   '427 Smith Center Apt. 785\nSouth Charleston, PE J5V 1N2',
#   'Mckinneyton',
#   'British Columbia',
#   'Germany',
#   '238-427-2860',
#   'benchmark bricks-and-clicks applications',
#   '1913-04-11',
#   1992,
#   '2021-02-23 15:30:36.594508',
#   '2021-02-23 15:30:36.594509',
#   '145.130.32.201'),
#  (772,
#   'Julie Barry',
#   'petersenjames@hotmail.com',
#   '336 Robert Forges Apt. 600\nNew Teresabury, NU G1M3X2',
#   'Michealtown',
#   'Yukon Territory',
#   'Slovenia',
#   '1-600-579-3622',
#   'repurpose B2C markets',
#   '1965-11-14',
#   1796,
#   '2021-02-23 15:30:36.595234',
#   '2021-02-23 15:30:36.595235',
#   '11.51.161.92'),
#  (773,
#   'Lawrence Farmer',
#   'patrickrodriguez@odonnell.com',
#   '0361 Cooper Parkways\nPort Melissaton, ON Y6H 4B3',
#   'Port Andrew',
#   'Northwest Territories',
#   'Timor-Leste',
#   '1 (222) 978-8763',
#   'seize strategic web-readiness',
#   '1924-03-06',
#   1057,
#   '2021-02-23 15:30:36.596069',
#   '2021-02-23 15:30:36.596070',
#   '107.108.188.120'),
#  (774,
#   'Michele Gutierrez',
#   'matthew60@hotmail.com',
#   '3566 Bradford Lodge\nPort Franciscoland, BC L6K9M8',
#   'East Jay',
#   'Prince Edward Island',
#   'Gibraltar',
#   '428.380.8523',
#   'generate turn-key content',
#   '1936-03-30',
#   1705,
#   '2021-02-23 15:30:36.596767',
#   '2021-02-23 15:30:36.596768',
#   '145.67.126.107'),
#  (775,
#   'Katrina Turner',
#   'ochavez@henson.net',
#   '6608 Kevin Villages\nSouth Christopher, NB T9N7A7',
#   'Roberthaven',
#   'Ontario',
#   'South Georgia and the South Sandwich Islands',
#   '776-405-9058 x749',
#   'streamline clicks-and-mortar schemas',
#   '1996-11-26',
#   1306,
#   '2021-02-23 15:30:36.597530',
#   '2021-02-23 15:30:36.597531',
#   '21.250.147.106'),
#  (776,
#   'James Black',
#   'shannon48@yahoo.com',
#   '99970 Gary Port Apt. 646\nEast Josephmouth, NU T2Y 5H4',
#   'Padillastad',
#   'Nunavut',
#   'Palau',
#   '947-996-7455 x817',
#   'redefine visionary e-services',
#   '1935-08-12',
#   1641,
#   '2021-02-23 15:30:36.598224',
#   '2021-02-23 15:30:36.598225',
#   '112.22.2.239'),
#  (777,
#   'Tammy Herman',
#   'lucasjohn@david-davenport.com',
#   '1723 Munoz Ports\nWolfechester, SK T7T 5T3',
#   'Port Tonyaside',
#   'Prince Edward Island',
#   'Ghana',
#   '(236) 788-5382 x037',
#   'envisioneer customized e-tailers',
#   '1975-01-22',
#   2447,
#   '2021-02-23 15:30:36.599172',
#   '2021-02-23 15:30:36.599174',
#   '162.92.207.48'),
#  (778,
#   'Brett Allen',
#   'wallsjoshua@perry.com',
#   '8487 Marshall Mills\nSouth Christinafurt, BC Y7P5C6',
#   'East Kimberlybury',
#   'Manitoba',
#   'Netherlands',
#   '787-155-1092',
#   'target vertical channels',
#   '1983-09-11',
#   1898,
#   '2021-02-23 15:30:36.600017',
#   '2021-02-23 15:30:36.600019',
#   '35.93.156.147'),
#  (779,
#   'Daniel Smith',
#   'jacobbarnett@hotmail.com',
#   '69579 Higgins Prairie Apt. 096\nPort Tony, YT N2C1L1',
#   'Lake Victoria',
#   'Nunavut',
#   'Armenia',
#   '235-126-3034',
#   'incentivize customized relationships',
#   '2006-11-14',
#   2106,
#   '2021-02-23 15:30:36.600776',
#   '2021-02-23 15:30:36.600777',
#   '114.45.4.96'),
#  (780,
#   'Sonya Marsh PhD',
#   'pbaker@hinton.net',
#   '4828 Bean Court Apt. 500\nAmyton, NT K9G 2C5',
#   'Schmidtberg',
#   'Prince Edward Island',
#   'India',
#   '1-188-194-4998',
#   'expedite rich users',
#   '1999-02-09',
#   1224,
#   '2021-02-23 15:30:36.601617',
#   '2021-02-23 15:30:36.601618',
#   '133.98.42.195'),
#  (781,
#   'Joshua Haynes',
#   'ortizjennifer@neal.com',
#   '4361 Debra Mall Apt. 255\nNew Jose, BC X6G6B2',
#   'Glovermouth',
#   'Newfoundland and Labrador',
#   'Estonia',
#   '978.503.1162',
#   'transition extensible vortals',
#   '1997-06-24',
#   1297,
#   '2021-02-23 15:30:36.602460',
#   '2021-02-23 15:30:36.602460',
#   '23.56.200.83'),
#  (782,
#   'John Ray',
#   'joshua81@yahoo.com',
#   '3548 Kelly Streets Apt. 931\nNorth Timothyberg, PE A4P1H2',
#   'North Christopher',
#   'Nunavut',
#   'Japan',
#   '268.788.2856',
#   'strategize robust methodologies',
#   '2004-06-06',
#   2093,
#   '2021-02-23 15:30:36.603129',
#   '2021-02-23 15:30:36.603130',
#   '185.108.224.133'),
#  (783,
#   'Colton Flores',
#   'yhayes@gmail.com',
#   '870 James Bypass Apt. 397\nTaraberg, BC T5A7P8',
#   'West Thomas',
#   'New Brunswick',
#   'Reunion',
#   '814-395-2400',
#   'unleash seamless channels',
#   '1936-07-21',
#   1435,
#   '2021-02-23 15:30:36.603801',
#   '2021-02-23 15:30:36.603802',
#   '57.229.249.230'),
#  (784,
#   'Phillip Vasquez',
#   'ilee@burton.com',
#   '535 Brown Mission Apt. 784\nNorth Wendy, NU X7N1M9',
#   'Davidville',
#   'Nova Scotia',
#   'Slovakia (Slovak Republic)',
#   '665 322 1256',
#   'whiteboard ubiquitous e-commerce',
#   '1910-10-28',
#   1665,
#   '2021-02-23 15:30:36.604731',
#   '2021-02-23 15:30:36.604732',
#   '40.53.128.70'),
#  (785,
#   'Michael Bartlett',
#   'tonijohnson@gmail.com',
#   '74850 Stevens Forges Suite 410\nEast Melissa, NB E1V 7V3',
#   'Jamesshire',
#   'Alberta',
#   'Brunei Darussalam',
#   '1-269-573-5596',
#   'architect global architectures',
#   '1928-03-01',
#   2471,
#   '2021-02-23 15:30:36.605472',
#   '2021-02-23 15:30:36.605473',
#   '220.177.242.77'),
#  (786,
#   'James Johnson',
#   'ssellers@gmail.com',
#   '430 Curtis Brooks\nSouth Jean, NS X1Y 3A3',
#   'Roberttown',
#   'Ontario',
#   'Heard Island and McDonald Islands',
#   '1 (616) 227-2382',
#   'incubate end-to-end partnerships',
#   '2010-08-15',
#   1431,
#   '2021-02-23 15:30:36.606136',
#   '2021-02-23 15:30:36.606137',
#   '200.165.14.209'),
#  (787,
#   'Mary Herring',
#   'richard66@hotmail.com',
#   '2475 Wilson Harbor Suite 277\nDerrickchester, NL K3E5M5',
#   'East Ryanhaven',
#   'Newfoundland and Labrador',
#   'Macao',
#   '839.249.2915',
#   'incubate dot-com channels',
#   '1935-09-16',
#   2441,
#   '2021-02-23 15:30:36.606848',
#   '2021-02-23 15:30:36.606849',
#   '138.50.124.206'),
#  (788,
#   'Michael Stevenson',
#   'rjackson@lopez.net',
#   '4979 King Underpass Apt. 456\nEast Michaelview, NL T3L6K9',
#   'Garytown',
#   'British Columbia',
#   'Cape Verde',
#   '568-827-4995',
#   'deliver synergistic e-tailers',
#   '2013-11-25',
#   1928,
#   '2021-02-23 15:30:36.607789',
#   '2021-02-23 15:30:36.607790',
#   '45.246.58.191'),
#  (789,
#   'Rachel Roberts',
#   'brownjonathan@hotmail.com',
#   '51700 Loretta Run\nSouth Crystal, QC R6V 7T9',
#   'Richardchester',
#   'Ontario',
#   'Poland',
#   '297.940.1676',
#   'aggregate robust architectures',
#   '1988-04-20',
#   2262,
#   '2021-02-23 15:30:36.608498',
#   '2021-02-23 15:30:36.608499',
#   '180.117.172.168'),
#  (790,
#   'Justin Hamilton',
#   'isaiahgutierrez@gmail.com',
#   '631 Melissa Square\nNew Alicia, BC B1E1N8',
# ...
#   'shawnzhang@hotmail.com',
#   '579 Powers Prairie\nPort Michaelton, NU K5X 3K7',
#   'Josephton',
#   'British Columbia',
#   'Aruba',
#   '(569) 120-3816 x070',
#   'engineer customized solutions',
#   '1955-12-08',
#   1562,
#   '2021-02-23 15:30:36.741477',
#   '2021-02-23 15:30:36.741478',
#   '195.92.187.193'),
#  (953,
#   'Brandon Anderson',
#   'scottmorris@hester.com',
#   '0654 Dixon Junctions Apt. 454\nJaredbury, SK R7S5S7',
#   'South Tonychester',
#   'Yukon Territory',
#   'United Kingdom',
#   '812 909 2205',
#   'transform intuitive interfaces',
#   '2009-10-18',
#   1938,
#   '2021-02-23 15:30:36.742461',
#   '2021-02-23 15:30:36.742462',
#   '168.106.11.17'),
#  (954,
#   'Laura Jordan',
#   'chad50@yahoo.com',
#   '0971 Baker Club Apt. 150\nEast Ryanshire, PE R3P 7E9',
#   'Lake Alicia',
#   'Ontario',
#   'Saint Kitts and Nevis',
#   '457-886-1621 x924',
#   'productize web-enabled vortals',
#   '1987-08-01',
#   1210,
#   '2021-02-23 15:30:36.743133',
#   '2021-02-23 15:30:36.743134',
#   '135.223.97.90'),
#  (955,
#   'Dylan Sullivan',
#   'valerie20@dunlap-morales.biz',
#   '8581 Kyle Hill Suite 731\nSouth Andrew, NT X9H5B9',
#   'Port Larrybury',
#   'Quebec',
#   'Austria',
#   '1-885-601-4138',
#   'incentivize cross-platform e-markets',
#   '1916-03-26',
#   1549,
#   '2021-02-23 15:30:36.743958',
#   '2021-02-23 15:30:36.743959',
#   '14.28.168.12'),
#  (956,
#   'Penny Robinson',
#   'christian57@gmail.com',
#   '0796 Hernandez Flats\nNorth Adambury, NB L7P9R3',
#   'Patrickside',
#   'Yukon Territory',
#   'French Southern Territories',
#   '993 273 3318',
#   'syndicate ubiquitous niches',
#   '1984-10-03',
#   2402,
#   '2021-02-23 15:30:36.744622',
#   '2021-02-23 15:30:36.744623',
#   '85.177.33.41'),
#  (957,
#   'Veronica Williams',
#   'arroyojennifer@bennett.com',
#   '770 Alan Tunnel\nNew Brycestad, NS J6N 7B1',
#   'West Veronicaville',
#   'Ontario',
#   'Malaysia',
#   '(342) 162-4207 x209',
#   'cultivate cross-platform supply-chains',
#   '1908-04-11',
#   1946,
#   '2021-02-23 15:30:36.745444',
#   '2021-02-23 15:30:36.745445',
#   '17.75.94.218'),
#  (958,
#   'Tina Jones',
#   'munozsamuel@hotmail.com',
#   '02331 Carlson Terrace\nSouth Jennifer, SK S1K6J5',
#   'Robertville',
#   'Alberta',
#   'Australia',
#   '389.604.1167',
#   'engage best-of-breed infrastructures',
#   '1935-12-14',
#   1668,
#   '2021-02-23 15:30:36.746156',
#   '2021-02-23 15:30:36.746157',
#   '26.52.11.227'),
#  (959,
#   'Sharon Bridges',
#   'fburton@mcbride.com',
#   '24676 Stephenson Ridges Apt. 486\nSouth Nathanmouth, YT M6V 2K9',
#   'Robertoport',
#   'Manitoba',
#   'Tuvalu',
#   '797.684.6841',
#   'enable dot-com content',
#   '1998-07-31',
#   2216,
#   '2021-02-23 15:30:36.746965',
#   '2021-02-23 15:30:36.746966',
#   '39.232.191.253'),
#  (960,
#   'Terry Stevens',
#   'nbryant@hotmail.com',
#   '843 Boyd Points\nNorth Ryan, NT J1T 4R6',
#   'Johnsonport',
#   'Prince Edward Island',
#   'Burundi',
#   '697.700.1894',
#   'synthesize 24/365 vortals',
#   '1966-03-23',
#   1236,
#   '2021-02-23 15:30:36.747657',
#   '2021-02-23 15:30:36.747658',
#   '96.54.68.26'),
#  (961,
#   'James Yates',
#   'george01@marshall.biz',
#   '233 Soto Camp\nWest Johnberg, NT L6C 4R2',
#   'Carrillotown',
#   'Northwest Territories',
#   'Slovenia',
#   '(563) 235-8278',
#   'target collaborative applications',
#   '1980-04-27',
#   2217,
#   '2021-02-23 15:30:36.748448',
#   '2021-02-23 15:30:36.748449',
#   '48.221.128.74'),
#  (962,
#   'Eric Carr',
#   'ana72@yahoo.com',
#   '60593 Anne Creek Apt. 901\nCervantesside, MB L8S 7Y3',
#   'Andersonton',
#   'Northwest Territories',
#   'Guatemala',
#   '1 (514) 841-9574',
#   'deploy dynamic vortals',
#   '1967-01-29',
#   2223,
#   '2021-02-23 15:30:36.749134',
#   '2021-02-23 15:30:36.749135',
#   '41.68.215.130'),
#  (963,
#   'David Romero',
#   'michaeldavis@gmail.com',
#   '9871 Lopez Trace Apt. 426\nKennedymouth, AB P4T 3C7',
#   'South Wendy',
#   'Yukon Territory',
#   'British Virgin Islands',
#   '(409) 460-0245',
#   'repurpose viral applications',
#   '2010-01-12',
#   2397,
#   '2021-02-23 15:30:36.749897',
#   '2021-02-23 15:30:36.749898',
#   '57.133.18.229'),
#  (964,
#   'Mark Kidd',
#   'joyce05@andrade.com',
#   '9455 Lloyd Spring\nStaceyfurt, BC P7J 4M2',
#   'West Danielleborough',
#   'Manitoba',
#   'Peru',
#   '337.414.0826',
#   'implement cross-platform experiences',
#   '2020-12-29',
#   1886,
#   '2021-02-23 15:30:36.750790',
#   '2021-02-23 15:30:36.750791',
#   '135.159.44.204'),
#  (965,
#   'Jesse Mendez',
#   'ericacarter@harris.com',
#   '1534 Adams Causeway\nPort Kimberlyview, NB L4A5K3',
#   'Port Rachel',
#   'Alberta',
#   'Yemen',
#   '1 (593) 406-0690',
#   'unleash holistic supply-chains',
#   '1984-05-12',
#   2410,
#   '2021-02-23 15:30:36.751656',
#   '2021-02-23 15:30:36.751657',
#   '83.150.196.127'),
#  (966,
#   'David Bates',
#   'ckelly@camacho-durham.biz',
#   '636 David Harbors Apt. 228\nWest Raymond, YT B5P3E9',
#   'Jamesville',
#   'Nunavut',
#   'Russian Federation',
#   '1 (784) 887-4149',
#   'incubate bleeding-edge communities',
#   '1946-02-06',
#   1933,
#   '2021-02-23 15:30:36.752510',
#   '2021-02-23 15:30:36.752511',
#   '175.17.2.68'),
#  (967,
#   'Jacob Thomas',
#   'kevinsanders@gmail.com',
#   '31559 Gill Corners\nWest William, NL S4R 8H7',
#   'Williamschester',
#   'Northwest Territories',
#   'Japan',
#   '(486) 360-0111',
#   'deliver best-of-breed systems',
#   '1966-10-10',
#   2344,
#   '2021-02-23 15:30:36.753254',
#   '2021-02-23 15:30:36.753255',
#   '58.25.48.91'),
#  (968,
#   'Peter Glover',
#   'benjamindunn@sellers.com',
#   '6027 Tina Extensions Suite 474\nPierceview, BC M2M 2E7',
#   'Port Richardmouth',
#   'Newfoundland and Labrador',
#   'United Arab Emirates',
#   '1-853-141-0770',
#   'expedite proactive systems',
#   '1951-07-02',
#   1246,
#   '2021-02-23 15:30:36.754096',
#   '2021-02-23 15:30:36.754097',
#   '83.197.124.121'),
#  (969,
#   'Carol Anderson',
#   'ashleymurphy@gmail.com',
#   '3342 Smith Passage\nEast Jessica, ON G5C5K2',
#   'East Amanda',
#   'Manitoba',
#   'Guam',
#   '+1 (565) 643-2889',
#   'grow mission-critical applications',
#   '1926-07-18',
#   1964,
#   '2021-02-23 15:30:36.754853',
#   '2021-02-23 15:30:36.754854',
#   '24.183.161.59'),
#  (970,
#   'Lee Flores',
#   'robin26@smith-johnston.info',
#   '9977 Michael Course\nEast Susan, NB B8M 6L9',
#   'Brownstad',
#   'Manitoba',
#   'Syrian Arab Republic',
#   '(141) 098-2742 x288',
#   'benchmark scalable infrastructures',
#   '1992-07-10',
#   2228,
#   '2021-02-23 15:30:36.755676',
#   '2021-02-23 15:30:36.755677',
#   '117.169.167.158'),
#  (971,
#   'Thomas Fowler',
#   'leslie69@evans.com',
#   '7298 Smith Valley\nKimberlyborough, BC V6L 3T6',
#   'Lake Devonberg',
#   'British Columbia',
#   'Sri Lanka',
#   '(703) 646-2308 x475',
#   'deploy robust deliverables',
#   '1909-01-27',
#   1795,
#   '2021-02-23 15:30:36.756597',
#   '2021-02-23 15:30:36.756598',
#   '49.195.199.42'),
#  (972,
#   'Scott Oconnor',
#   'holmesashley@schmidt-buchanan.com',
#   '37236 Johnson Divide\nWhitemouth, SK H5H 6C8',
#   'West Victoria',
#   'Manitoba',
#   "Lao People's Democratic Republic",
#   '519-219-9383 x859',
#   'empower dynamic initiatives',
#   '1998-05-07',
#   1828,
#   '2021-02-23 15:30:36.757513',
#   '2021-02-23 15:30:36.757514',
#   '128.109.12.233'),
#  (973,
#   'Eric Swanson',
#   'abrown@best-small.info',
#   '540 Jeffrey Shore Suite 281\nNorth Rebeccaville, MB A4E 2E1',
#   'South Amandastad',
#   'Nunavut',
#   'Germany',
#   '(636) 450-1613 x289',
#   'expedite efficient infrastructures',
#   '2012-07-28',
#   1487,
#   '2021-02-23 15:30:36.758350',
#   '2021-02-23 15:30:36.758351',
#   '21.249.68.56'),
#  (974,
#   'David Zuniga',
#   'xmaddox@griffin.com',
#   '23283 Barr Port Suite 932\nOchoaport, NU A6R8P5',
#   'Angelaton',
#   'Nova Scotia',
#   'Slovakia (Slovak Republic)',
#   '114.958.6224',
#   'reinvent virtual channels',
#   '2007-12-25',
#   2018,
#   '2021-02-23 15:30:36.759170',
#   '2021-02-23 15:30:36.759171',
#   '164.255.197.174'),
#  (975,
#   'Thomas Hunt',
#   'shannon00@gmail.com',
#   '73464 Villanueva Crest\nTaylorborough, NL M5T 6X9',
#   'Mcmahonfurt',
#   'Manitoba',
#   'Myanmar',
#   '1 (391) 647-4051',
#   'streamline extensible e-markets',
#   '2012-04-30',
#   1783,
#   '2021-02-23 15:30:36.759884',
#   '2021-02-23 15:30:36.759885',
#   '99.155.250.38'),
#  (976,
#   'Andrea Hughes',
#   'zpitts@yahoo.com',
#   '4444 Gregory Village\nSouth Sean, ON E8X 4V4',
#   'Lewistown',
#   'Saskatchewan',
#   'Papua New Guinea',
#   '523 103 8582',
#   'envisioneer turn-key schemas',
#   '1949-05-27',
#   1837,
#   '2021-02-23 15:30:36.760570',
#   '2021-02-23 15:30:36.760571',
#   '122.231.176.233'),
#  (977,
#   'Adrienne Moore',
#   'guzmanwilliam@hotmail.com',
#   '094 Janice Gateway\nFraziermouth, YT M4C 5S3',
#   'West Meagan',
#   'Nunavut',
#   'Panama',
#   '964.400.6687',
#   'benchmark leading-edge eyeballs',
#   '1970-06-28',
#   2470,
#   '2021-02-23 15:30:36.761300',
#   '2021-02-23 15:30:36.761301',
#   '14.138.217.60'),
#  (978,
#   'Todd Cummings',
#   'jessicamoore@mueller.com',
#   '52669 Francisco Cliffs\nChristineview, BC Y9A9Y9',
#   'North Donaldmouth',
#   'British Columbia',
#   'Chile',
#   '+1 (782) 530-3849',
#   'empower ubiquitous synergies',
#   '2015-10-02',
#   1850,
#   '2021-02-23 15:30:36.762301',
#   '2021-02-23 15:30:36.762302',
#   '123.173.206.164'),
#  (979,
#   'James Roberts',
#   'frank83@gmail.com',
#   '4625 Julie Oval Suite 836\nAshleychester, NS C9E 3V9',
#   'Port Ashleyburgh',
#   'Newfoundland and Labrador',
#   'Jersey',
#   '(652) 880-8485 x459',
#   'benchmark user-centric functionalities',
#   '1953-10-01',
#   1421,
#   '2021-02-23 15:30:36.762985',
#   '2021-02-23 15:30:36.762986',
#   '166.125.76.211'),
#  (980,
#   'Emily Becker',
#   'teresa39@hotmail.com',
#   '5408 Price Street\nLake Robert, SK C5B7J5',
#   'Ericaport',
#   'Manitoba',
#   'Malaysia',
#   '(683) 822-0508 x673',
#   'incubate bricks-and-clicks action-items',
#   '1929-11-29',
#   1735,
#   '2021-02-23 15:30:36.763652',
#   '2021-02-23 15:30:36.763654',
#   '56.54.214.65'),
#  (981,
#   'Michael Lee',
#   'ashley14@lozano.info',
#   '541 Sarah Creek Apt. 727\nPalmerside, AB E7J8Y2',
#   'Brendamouth',
#   'Ontario',
#   'Bulgaria',
#   '158 542 4909',
#   'revolutionize killer applications',
#   '1947-02-15',
#   1268,
#   '2021-02-23 15:30:36.764423',
#   '2021-02-23 15:30:36.764424',
#   '161.92.90.184'),
#  (982,
#   'Sharon Harrell',
#   'shunt@gmail.com',
#   '15663 Lawrence Cape\nMartinburgh, NL E4T7C9',
#   'Port Patrick',
#   'British Columbia',
#   'Rwanda',
#   '1 (138) 739-9913',
#   'grow 24/7 eyeballs',
#   '1952-08-01',
#   1496,
#   '2021-02-23 15:30:36.765121',
#   '2021-02-23 15:30:36.765122',
#   '113.90.200.163'),
#  (983,
#   'Rebecca Bennett',
#   'gregorygonzalez@yahoo.com',
#   '449 Jim Mountain Apt. 375\nKimberlyberg, NL A7P7L8',
#   'Daniellehaven',
#   'Manitoba',
#   'Burundi',
#   '893.108.4470',
#   'synthesize extensible e-tailers',
#   '1946-03-05',
#   1191,
#   '2021-02-23 15:30:36.765850',
#   '2021-02-23 15:30:36.765851',
#   '73.210.8.134'),
#  (984,
#   'Brandi Johnson',
#   'ellen42@gonzalez-ward.biz',
#   '065 Jones Ferry Apt. 631\nEast Thomaschester, NU N2K6X9',
#   'Tonyberg',
#   'British Columbia',
#   'Moldova',
#   '(267) 650-2882 x765',
#   'synthesize rich interfaces',
#   '1919-12-15',
#   1721,
#   '2021-02-23 15:30:36.766711',
#   '2021-02-23 15:30:36.766712',
#   '90.211.174.123'),
#  (985,
#   'Brittany Hoover',
#   'dnavarro@yahoo.com',
#   '117 Bryan Creek\nSouth Lindsey, ON A6E5M6',
#   'North Melindaland',
#   'Newfoundland and Labrador',
#   'Chile',
#   '157-873-0661',
#   'seize end-to-end info-mediaries',
#   '1986-08-31',
#   1425,
#   '2021-02-23 15:30:36.767362',
#   '2021-02-23 15:30:36.767363',
#   '122.168.12.206'),
#  (986,
#   'Jeffrey Rojas',
#   'sanfordtiffany@becker-webb.net',
#   '923 Richard Inlet\nWest Robinshire, ON V1K3E3',
#   'Silvaland',
#   'New Brunswick',
#   'Portugal',
#   '897 456 0425',
#   'synergize cross-media communities',
#   '1991-11-03',
#   1752,
#   '2021-02-23 15:30:36.768262',
#   '2021-02-23 15:30:36.768263',
#   '93.210.10.104'),
#  (987,
#   'Veronica Williamson',
#   'thomaslindsay@kent-allen.com',
#   '39508 Anderson Trail\nHinesbury, NB J9Y 4B5',
#   'Woodchester',
#   'Saskatchewan',
#   'Northern Mariana Islands',
#   '+1 (871) 477-4177',
#   'reinvent out-of-the-box functionalities',
#   '1965-09-11',
#   1717,
#   '2021-02-23 15:30:36.769198',
#   '2021-02-23 15:30:36.769199',
#   '15.191.156.170'),
#  (988,
#   'Yvonne Mendez',
#   'ehayden@mills.com',
#   '05834 Brenda Harbor\nTarafurt, BC P1B2M8',
#   'Carolynshire',
#   'Manitoba',
#   'Lesotho',
#   '1 (313) 478-1067',
#   'deliver frictionless portals',
#   '1909-07-31',
#   1102,
#   '2021-02-23 15:30:36.769949',
#   '2021-02-23 15:30:36.769950',
#   '66.112.251.173'),
#  (989,
#   'Shaun Vazquez',
#   'lisa53@mayo.com',
#   '72004 Stacy Ports Suite 557\nLake Moniqueville, NL N5Y3P9',
#   'South Jackport',
#   'Alberta',
#   'Canada',
#   '+1 (299) 285-8238',
#   'incentivize synergistic experiences',
#   '1959-03-02',
#   2123,
#   '2021-02-23 15:30:36.770691',
#   '2021-02-23 15:30:36.770692',
#   '64.152.9.221'),
#  (990,
#   'Jennifer Li',
#   'christopher91@hotmail.com',
#   '9547 Dunn Knolls\nNew Sierrabury, QC B9T4H3',
#   'Deborahport',
#   'Newfoundland and Labrador',
#   'Netherlands Antilles',
#   '1-840-871-6540',
#   'iterate 24/365 e-services',
#   '1994-11-08',
#   1277,
#   '2021-02-23 15:30:36.771352',
#   '2021-02-23 15:30:36.771353',
#   '207.35.210.242'),
#  (991,
#   'Kayla Jones',
#   'samuel95@vargas.com',
#   '29659 Crystal Hills\nEast Adriana, MB J7X4K3',
#   'New Brandonfurt',
#   'Nunavut',
#   'Syrian Arab Republic',
#   '(117) 066-9565 x632',
#   'synthesize interactive architectures',
#   '1913-12-02',
#   1378,
#   '2021-02-23 15:30:36.772241',
#   '2021-02-23 15:30:36.772242',
#   '2.212.147.41'),
#  (992,
#   'Brittany Hopkins',
#   'zmorris@martin.com',
#   '6062 Brandy Lock\nSouth Normanport, NU E5L 3L9',
#   'Laceyshire',
#   'British Columbia',
#   'Turks and Caicos Islands',
#   '1 (894) 077-8217',
#   'innovate visionary metrics',
#   '1998-10-22',
#   1645,
#   '2021-02-23 15:30:36.773134',
#   '2021-02-23 15:30:36.773135',
#   '108.173.148.71'),
#  (993,
#   'Jeffrey Becker',
#   'katie74@scott-wilkinson.com',
#   '35431 Wilkins Springs\nJameston, MB H9X4K2',
#   'Rodriguezmouth',
#   'Quebec',
#   'Papua New Guinea',
#   '(638) 342-0052 x353',
#   'transform mission-critical partnerships',
#   '1920-08-23',
#   1427,
#   '2021-02-23 15:30:36.773984',
#   '2021-02-23 15:30:36.773985',
#   '54.100.132.133'),
#  (994,
#   'Crystal Navarro',
#   'jwerner@yahoo.com',
#   '524 Autumn Drives\nPort Wesley, MB Y1C 5V7',
#   'Lake Karen',
#   'Nova Scotia',
#   'Trinidad and Tobago',
#   '(447) 763-0136',
#   'extend bricks-and-clicks info-mediaries',
#   '1962-05-17',
#   2318,
#   '2021-02-23 15:30:36.774668',
#   '2021-02-23 15:30:36.774669',
#   '65.94.160.63'),
#  (995,
#   'Stacy Carter',
#   'robertchang@snyder.com',
#   '369 Garcia Pine\nJeffreychester, NU N2E 4H7',
#   'Lake Monicastad',
#   'Yukon Territory',
#   'Bolivia',
#   '(486) 683-4282 x272',
#   'deploy dot-com convergence',
#   '1957-03-12',
#   1012,
#   '2021-02-23 15:30:36.775640',
#   '2021-02-23 15:30:36.775641',
#   '129.187.112.50'),
#  (996,
#   'Christina Figueroa',
#   'barreraelizabeth@gmail.com',
#   '4974 Lisa Lakes Suite 625\nSamanthaville, BC P1V 1J4',
#   'Robinmouth',
#   'Nunavut',
#   'Bolivia',
#   '(521) 796-5668 x951',
#   'exploit sticky deliverables',
#   '1970-11-17',
#   1373,
#   '2021-02-23 15:30:36.776367',
#   '2021-02-23 15:30:36.776368',
#   '177.246.18.137'),
#  (997,
#   'Tiffany Smith',
#   'stephaniestewart@gmail.com',
#   '665 Jackson Trail Apt. 541\nAmberfort, AB B8V7S9',
#   'Janicestad',
#   'Ontario',
#   'El Salvador',
#   '591-124-0779',
#   'enable dynamic info-mediaries',
#   '1916-05-21',
#   1361,
#   '2021-02-23 15:30:36.777156',
#   '2021-02-23 15:30:36.777157',
#   '183.18.149.177'),
#  (998,
#   'Kevin Reed',
#   'greenwilliam@larsen-collins.com',
#   '451 Fleming Avenue\nSmithview, PE S7A 1E2',
#   'Brianshire',
#   'Alberta',
#   'Dominica',
#   '+1 (589) 707-7138',
#   'matrix cross-media e-business',
#   '1909-12-04',
#   1853,
#   '2021-02-23 15:30:36.778073',
#   '2021-02-23 15:30:36.778074',
#   '75.200.20.213'),
#  (999,
#   'Eric Green',
#   'staceylee@gmail.com',
#   '217 White Ways Suite 569\nEast Allisonton, ON P7M7G7',
#   'Lake Joshuaside',
#   'Alberta',
#   'Uganda',
#   '742.117.4803',
#   'maximize cross-platform models',
#   '1962-11-16',
#   1219,
#   '2021-02-23 15:30:36.778821',
#   '2021-02-23 15:30:36.778822',
#   '130.144.62.64'),
#  (1000,
#   'Katherine Santos',
#   'dwilliams@gmail.com',
#   '5601 Katherine Overpass Suite 190\nLake Andrew, BC T5J8C3',
#   'Paulport',
#   'New Brunswick',
#   'Montenegro',
#   '(404) 383-4235',
#   'seize visionary functionalities',
#   '1949-03-23',
#   1914,
#   '2021-02-23 15:30:36.779487',
#   '2021-02-23 15:30:36.779488',
#   '25.97.7.132')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
from pprint import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT name, heatmap FROM people WHERE heatmap > 1500 LIMIT 20 """

myCursor.execute("SELECT name, heatmap FROM people WHERE heatmap > 1500 LIMIT 20")
results = myCursor.fetchall()
pprint(results)
# Out:
# [('Alexander Knight', 2035),
#  ('Michelle Robinson', 1720),
#  ('Joseph Burton', 1781),
#  ('Elijah Pena', 1713),
#  ('Justin Davis', 1729),
#  ('Jeffrey Berry', 2381),
#  ('Jared Galloway', 1790),
#  ('Judith Simpson', 2214),
#  ('Michael Pena', 1761),
#  ('Cory Strickland', 1915),
#  ('Travis Fernandez', 1665),
#  ('Sherry Ford', 2019),
#  ('Lori Lewis', 2487),
#  ('Stephanie Richard', 1864),
#  ('Laura Brown', 2089),
#  ('Gregory Ramos', 2066),
#  ('Chad Snyder', 1637),
#  ('Adam Nguyen', 1849),
#  ('Nathan Bennett', 1891),
#  ('Margaret Coffey', 1973)]

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
